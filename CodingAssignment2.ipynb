# %%
#Question 10
secret_word = "apple"
allowed_guesses = 10

while allowed_guesses > 0:
  guess = input("Guess the word: ")
  if guess == secret_word:
    print("Congratulations! You guessed the word correctly.")
    break
  else:
    allowed_guesses -= 1
    print("Incorrect guess. Try again.")

if allowed_guesses > 0:
  print("You have", allowed_guesses, "guesses remaining.")
else:
  print("Sorry, you have used up all your guesses. The secret word was", secret_word)

#Question 11
total = 0
for num in range(1, 11):
  total += num

print("The sum of integers from 1 to 10 is:", total)

#Question 12
def factorial(n):
  result = 1
  for i in range(1, n+1):
    result *= i
  return result

#Question 13
count = 0
total_sum = 0
product = 1

while count < 10:
  try:
    number = float(input("Enter a number: "))
    total_sum += number
    product *= number
    count += 1
  except ValueError:
    print("Invalid input. Please enter a valid number.")

average = total_sum / 10

print(f"Sum: {total_sum}")
print(f"Product: {product}")
print(f"Average: {average}")

#Question 15
calendar = [[] for _ in range(12)]

for month in calendar:
  weeks = [[] for _ in range(4)]
  month.extend(weeks)

#Question 16
month_names = ('January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December')

days_in_month = (31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31)

month_dict = {}

for i in range(len(month_names)):
  month_dict[month_names[i]] = days_in_month[i]

print(month_dict)

#Question 17
numbers = list(range(1, 11))
output = ", ".join(str(num) for num in numbers)
print(output)

#Question 18
def generate_calendar(year, month):
  import calendar

  cal_data = calendar.monthcalendar(year, month)

  calendar_weeks = [[str(day) + " week" for day in week] for week in cal_data]

  return calendar_weeks

# Example usage
year = 2022
month = 1
calendar_data = generate_calendar(year, month)

for week in calendar_data:
    print(week)

#Question 19
calendar = [[] for _ in range(52)]

#Question 20
def func_a():
  print("Hello, this is func_a!")

func_a()

b = func_a

b()

#Question 21
import math

def hypotenuse(num1, num2):
  result = math.sqrt(num1**2 + num2**2)
  print(result)

hypotenuse(3.5, 4.2)

hypotenuse(3, 4)

hypotenuse(5, 3.8)

#Question 22
def calculator(num1, num2, operation='addition', output_format='floating point'):
    
  if operation == 'addition':
      result = num1 + num2
  elif operation == 'subtraction':
      result = num1 - num2
  elif operation == 'multiplication':
      result = num1 * num2
  elif operation == 'division':
      result = num1 / num2
  else:
      return 'Invalid operation'

  if output_format == 'integer':
      result = int(result)

  return result

#Question 23
calculator(2, 3.0)
calculator(2, 3.0)
